# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#RentListingInquries" data-toc-modified-id="RentListingInquries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>RentListingInquries</a></span><ul class="toc-item"><li><span><a href="#基本信息" data-toc-modified-id="基本信息-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>基本信息</a></span></li><li><span><a href="#导入工具包" data-toc-modified-id="导入工具包-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>导入工具包</a></span></li><li><span><a href="#导入数据" data-toc-modified-id="导入数据-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>导入数据</a></span></li><li><span><a href="#基本信息" data-toc-modified-id="基本信息-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>基本信息</a></span></li><li><span><a href="#特征分析" data-toc-modified-id="特征分析-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>特征分析</a></span></li></ul></li><li><span><a href="#数据探索" data-toc-modified-id="数据探索-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>数据探索</a></span><ul class="toc-item"><li><span><a href="#interest_level" data-toc-modified-id="interest_level-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>interest_level</a></span></li><li><span><a href="#price" data-toc-modified-id="price-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>price</a></span></li><li><span><a href="#bathrooms" data-toc-modified-id="bathrooms-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>bathrooms</a></span></li><li><span><a href="#bedrooms" data-toc-modified-id="bedrooms-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>bedrooms</a></span></li><li><span><a href="#display_address" data-toc-modified-id="display_address-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>display_address</a></span></li><li><span><a href="#manager_id" data-toc-modified-id="manager_id-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>manager_id</a></span></li><li><span><a href="#street_address" data-toc-modified-id="street_address-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>street_address</a></span></li><li><span><a href="#created" data-toc-modified-id="created-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>created</a></span></li><li><span><a href="#longitude&amp;latitude" data-toc-modified-id="longitude&amp;latitude-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>longitude&amp;latitude</a></span></li><li><span><a href="#description" data-toc-modified-id="description-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>description</a></span></li><li><span><a href="#features" data-toc-modified-id="features-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>features</a></span></li><li><span><a href="#building_id、listing_id" data-toc-modified-id="building_id、listing_id-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>building_id、listing_id</a></span></li><li><span><a href="#photos" data-toc-modified-id="photos-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>photos</a></span></li></ul></li></ul></div>

# %% [markdown]
# # RentListingInquries

# %% [markdown]
# ## 基本信息
#     bathrooms: 浴室的数量number of bathrooms
#     bedrooms: 卧室数量number of bedrooms
#     building_id: ID号
#     created:
#     description: 描述
#     display_address:
#     features: 关于这间公寓的功能列表a list of features about this apartment
#     latitude: 纬度
#     listing_id
#     longitude: 经度
#     manager_id
#     photos: 照片链接列表a list of photo links. You are welcome to download the pictures yourselves from renthop's site, but they are the same as imgs.zip.
#     price: 以美元计算in USD
#     street_address: 街道地址
#     interest_level: 这是目标变量。它有3个类别：'高'，'中等'，'低'this is the target variable. It has 3 categories: 'high', 'medium', 'low'
#     共15维特征

# %% [markdown]
# ## 导入工具包

# %%
# 数据导入与处理
import numpy as np
import pandas as pd
# 数据可视化
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 导入数据

# %%
dpath = './data/'
train = pd.read_json(dpath+'train.json')
train.head()
# Out:
#         bathrooms  bedrooms                       building_id  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 10000         1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 100013        1.0         4                                 0
#
#                     created  \
# 10      2016-06-24 07:54:24
# 10000   2016-06-12 12:19:27
# 100004  2016-04-17 03:26:41
# 100007  2016-04-18 02:22:02
# 100013  2016-04-28 01:32:41
#
#                                               description  \
# 10      A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 10000
# 100004  Top Top West Village location, beautiful Pre-w...
# 100007  Building Amenities - Garage - Garden - fitness...
# 100013  Beautifully renovated 3 bedroom flex 4 bedroom...
#
#             display_address  \
# 10      Metropolitan Avenue
# 10000       Columbus Avenue
# ...

# %%
test = pd.read_json(dpath+'test.json')
test.head()
# Out:
#         bathrooms  bedrooms                       building_id  \
# 0             1.0         1  79780be1514f645d7e6be99a3de696c5
# 1             1.0         2                                 0
# 100           1.0         1  3dbbb69fd52e0d25131aa1cd459c87eb
# 1000          1.0         2  783d21d013a7e655bddc4ed0d461cc5e
# 100000        2.0         2  6134e7c4dd1a98d9aee36623c9872b49
#
#                     created  \
# 0       2016-06-11 05:29:41
# 1       2016-06-24 06:36:34
# 100     2016-06-03 04:29:40
# 1000    2016-06-11 06:17:35
# 100000  2016-04-12 05:24:17
#
#                                               description  \
# 0       Large with awesome terrace--accessible via bed...
# 1       Prime Soho - between Bleecker and Houston - Ne...
# 100             New York chic has reached a new level ...
# 1000    Step into this fantastic new Construction in t...
# 100000  ~Take a stroll in Central Park, enjoy the ente...
#
#               display_address  \
# ...

# %% [markdown]
# ## 基本信息

# %%
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49352 entries, 10 to 99994
# Data columns (total 15 columns):
# bathrooms          49352 non-null float64
# bedrooms           49352 non-null int64
# building_id        49352 non-null object
# created            49352 non-null object
# description        49352 non-null object
# display_address    49352 non-null object
# features           49352 non-null object
# latitude           49352 non-null float64
# listing_id         49352 non-null int64
# longitude          49352 non-null float64
# manager_id         49352 non-null object
# photos             49352 non-null object
# price              49352 non-null int64
# street_address     49352 non-null object
# interest_level     49352 non-null object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 6.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74659 entries, 0 to 99999
# Data columns (total 14 columns):
# bathrooms          74659 non-null float64
# ...

# %% [markdown]
# ## 特征分析
#
# 特征类型|特征
# - | -
# 连续型数值|price
# 离散性数值|bathrooms、bedrooms
# 高基数特征|display_address、manager_id、street_address
# 时间型|created
# 地理位置型|longitude、latitude
# 文本型|description
# 稀疏特征|features
# id型特征|building_id、listing_id
# 网址型|photos
# 合计|14维特征

# %% [markdown]
# train和text都没有缺失值

# %%
target=train['interest_level']
# building_id 对target 无影响,删除
#train.drop(['building_id'],axis=1, inplace=True)
# 测试数据中的building_id 保存起来, 提交数据的时候用
#test_ID = test['building_id']
#test = test.drop('building_id',axis=1)

# %% [markdown]
# # 数据探索

# %% [markdown]
# ## interest_level

# %%
# interest_level, 高中低, 三个取值
sns.countplot(target)

# %% [markdown]
# target各取值分类不均衡

# %% [markdown]
# ## price

# %%
# price与target

plt.scatter(range(train.shape[0]),np.sort(train.price.values))
plt.xlabel('index',fontsize=12)
plt.ylabel('price',fontsize=12)
# Out:
# Text(0,0.5,'price')

# %% [markdown]
# 个别点price比较大,当作异常点,删除

# %%
# 原数据斜度太大, 取log变换
sns.distplot(np.log(train['price']))

# %%
sns.stripplot(x=target,y=train['price'],jitter=True)

# %% [raw]
# train = train[train.price<10000]

# %% [markdown]
# ## bathrooms

# %%
# 查看分布
sns.countplot(train['bathrooms'])

# %%
# 与target
plt.figure(figsize=(15,6))
sns.countplot(train['bathrooms'],hue=target)

# %% [markdown]
# ## bedrooms

# %%
# 查看分布
sns.countplot(train['bedrooms'])

# %%
# 与target
plt.figure(figsize=(15,6))
sns.countplot(train['bedrooms'],hue=target)

# %% [markdown]
# ## display_address

# %%
counts = train['display_address'].value_counts()
counts
# Out:
# Broadway                           438
# East 34th Street                   355
# Second Avenue                      349
# Wall Street                        332
# West 37th Street                   287
# West Street                        258
# First Avenue                       244
# Gold Street                        241
# Washington Street                  237
# York Avenue                        228
# John Street                        214
# Water Street                       214
# East 39th Street                   200
# East 89th Street                   195
# West 54th Street                   193
# Lexington Avenue                   189
# Fifth Avenue                       189
# West 42nd Street                   184
# Christopher Street                 180
# Third Avenue                       178
# Columbus Avenue                    177
# W 37 St.                           176
# East 35th Street                   174
# West 34th Street                   169
# ...

# %%
# 对数据进行log变换
plt.hist(counts,bins=50,log=True)
# Out:
# (array([7.907e+03, 3.800e+02, 1.680e+02, 7.900e+01, 6.400e+01, 4.100e+01,
#         3.300e+01, 3.100e+01, 2.300e+01, 1.500e+01, 1.500e+01, 1.000e+01,
#         1.000e+01, 5.000e+00, 1.000e+00, 6.000e+00, 7.000e+00, 2.000e+00,
#         4.000e+00, 2.000e+00, 5.000e+00, 3.000e+00, 2.000e+00, 0.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 3.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  1.  ,   9.74,  18.48,  27.22,  35.96,  44.7 ,  53.44,  62.18,
#          70.92,  79.66,  88.4 ,  97.14, 105.88, 114.62, 123.36, 132.1 ,
#         140.84, 149.58, 158.32, 167.06, 175.8 , 184.54, 193.28, 202.02,
#         210.76, 219.5 , 228.24, 236.98, 245.72, 254.46, 263.2 , 271.94,
# ...

# %% [markdown]
# ## manager_id

# %%
count_id = train['manager_id'].value_counts()
count_id
# Out:
# e6472c7237327dd3903b3d6f6a94515a    2533
# 6e5c10246156ae5bdcd9b487ca99d96a     711
# 8f5a9c893f6d602f4953fcc0b8e6e9b4     409
# 62b685cc0d876c3a1a51d63a0d6a8082     402
# cb87dadbca78fad02b388dc9e8f25a5b     373
# 9df32cb8dda19d3222d66e69e258616b     330
# b7de4cb395920136663132057fa89d84     320
# 2aa9bfa5f67ed9997ea341dee8a3a271     316
# ad3d8ddc52c7e0859b5c6c7f7949c3bd     305
# c9c33695ee2a2f818e9f1d8f7d1c4b39     299
# 1fb46c4a72bcf764ac35fc23f394760d     289
# d2bce61e0e0079ebdc8c281e415e045b     276
# 5599e962719af3ccc2976855c2d5893c     256
# aa9e353a6b43b125cbc89cb751090a9e     246
# 62826f3ae01f2ddc93b9cd28c659ab2b     233
# 8b53ccf4338806ab1be3dd0267711649     222
# 612a00076aefe8c98d1df4835640c74b     214
# dbbb6b990661b1e507a387f019bcb1a0     212
# 8262449f40e9117f7a9ea49b4a333993     210
# b209e2c4384a64cc307c26759ee0c651     210
# fc81b75568d3655a922523cb0d77ea5b     206
# d1737922fe92ccb0dc37ba85589e6415     196
# 1067e078446a7897d2da493d2f741316     191
# ...

# %% [markdown]
# e6472c7237327dd3903b3d6f6a94515a的房子特别多

# %%
# 对数据进行log变换
plt.hist(count_id,bins=50,log=True)
# Out:
# (array([3.289e+03, 1.320e+02, 2.600e+01, 1.300e+01, 8.000e+00, 4.000e+00,
#         4.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([1.00000e+00, 5.16400e+01, 1.02280e+02, 1.52920e+02, 2.03560e+02,
#         2.54200e+02, 3.04840e+02, 3.55480e+02, 4.06120e+02, 4.56760e+02,
#         5.07400e+02, 5.58040e+02, 6.08680e+02, 6.59320e+02, 7.09960e+02,
#         7.60600e+02, 8.11240e+02, 8.61880e+02, 9.12520e+02, 9.63160e+02,
# ...

# %% [markdown]
# ## street_address

# %%
count_add = train['street_address'].value_counts()
count_add
# Out:
# 3333 Broadway                174
# 505 West 37th Street         167
# 200 Water Street             160
# 90 Washington Street         142
# 100 Maiden Lane              131
# 401 East 34th Street         129
# 2 Gold Street                120
# 1 West Street                119
# 100 John Street              115
# 95 Wall Street               106
# 340 East 29th Street          98
# 50 West 34th Street           94
# 95 Christopher Street         93
# 8 Spruce Street               88
# 145 East 16th Street          87
# 888 Eighth Avenue             85
# 550 West 54th Street          84
# 10 Hanover Square             83
# 166 Second Avenue             82
# 505 W 37 St.                  80
# 1 West St.                    79
# 561 10 Ave.                   76
# 140 East 46th Street          75
# 236 East 36th Street          75
# 1 Astor Place                 74
# 45 Wall Street                71
# 200 East 72nd Street          68
# 260 West 54th Street          68
# ...

# %%
# 对数据进行log变换
plt.hist(count_add,bins=50,log=True)
# Out:
# (array([1.308e+04, 9.430e+02, 5.560e+02, 2.180e+02, 1.930e+02, 8.200e+01,
#         6.800e+01, 4.000e+01, 4.100e+01, 2.300e+01, 2.300e+01, 1.200e+01,
#         1.000e+01, 8.000e+00, 1.100e+01, 6.000e+00, 5.000e+00, 6.000e+00,
#         1.000e+00, 4.000e+00, 1.000e+00, 4.000e+00, 2.000e+00, 3.000e+00,
#         2.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  1.  ,   4.46,   7.92,  11.38,  14.84,  18.3 ,  21.76,  25.22,
#          28.68,  32.14,  35.6 ,  39.06,  42.52,  45.98,  49.44,  52.9 ,
#          56.36,  59.82,  63.28,  66.74,  70.2 ,  73.66,  77.12,  80.58,
#          84.04,  87.5 ,  90.96,  94.42,  97.88, 101.34, 104.8 , 108.26,
# ...

# %% [markdown]
# ## created

# %%
# 将日期转换为pd.datetime, 并选取其中的data
created_date = pd.to_datetime(train['created']).dt.date
#对每个日期计数, 并以日期排序
created_date = created_date.value_counts().sort_index()

# %%
# 将日期可视化
ax = plt.subplot(111)
ax.bar(created_date.index,created_date.values,alpha=0.8)
ax.xaxis_date()
plt.xticks(rotation=-90)
plt.show()

# %%
# 以时间顺序为x轴
#plt.xticks(list(created_date.index[::5]), rotation='vertical')
created_hour = pd.to_datetime(train['created']).dt.hour
#created_hour = created_hour.value_counts().sort_index()
#sns.barplot(x=created_hour.index, y=created_hour.values)

plt.figure(figsize=(15,6))
sns.countplot(created_hour, hue=target)

# %% [markdown]
# ## longitude&latitude

# %%
#  避免出现极端情况, 取train['longitude']的 分为数在(1,99)
rang = (train['longitude']>np.percentile(train['longitude'],1)
       )&(train['longitude']<np.percentile(train['longitude'],99)
         )

sns.distplot(train.loc[rang,['longitude']], bins=50)
plt.xticks(rotation=-45)
# Out:
# (array([-74.05 , -74.025, -74.   , -73.975, -73.95 , -73.925, -73.9  ,
#         -73.875, -73.85 , -73.825]), <a list of 10 Text xticklabel objects>)

# %%
#  避免出现极端情况, 取train['latitude']的 分位数在(1,99)
rang = (train['latitude']>np.percentile(train['latitude'],1)
       ) & (train['latitude']<np.percentile(train['latitude'],99)
           )
sns.distplot(train.loc[rang,['latitude']], bins=50)

# %% [markdown]
# 联合经纬度,在地图上标点
# from mpl_toolkits.basemap import Basemap
# from matplotlib import cm
# west,south,east,north =-74.02,40.64,-73.85,40.86
# fig =plt.figure(figsize=(16,12))
# ax = fig.add_subplot(111)
# m=Basemap(projection='merc',
#           llcrnrlat=south,urcrnrlat=north,
#           llcrnrlon=west,urcrnrlon=east,
#           lat_ts=south,resolution='i')
# x,y=m(train_df['longitude'].values,train_df['latitude'].values)
# m.hexbin(x,y,gridsize=200,bins='log',cmap=cm.YlOrRd_r)

# %% [markdown]
# ## description

# %% [markdown]
# 文本信息太复杂, 不对其进行分析, 只提取其语句长度

# %%
train['description'].apply(len).value_counts()
# Out:
# 8       1646
# 0       1444
# 24       335
# 1        240
# 105      131
# 572       86
# 390       84
# 535       84
# 477       83
# 605       83
# 356       83
# 569       82
# 378       81
# 424       79
# 589       79
# 514       78
# 498       77
# 529       77
# 590       76
# 507       75
# 548       75
# 635       75
# 151       75
# 636       74
# 436       74
# 626       74
# 603       73
# 655       73
# 508       73
# 599       73
#         ...
# 1773       1
# 1677       1
# 3020       1
# 2668       1
# 2508       1
# 2348       1
# 2188       1
# 2124       1
# 1806       1
# 1902       1
# 1776       1
# 2062       1
# 1680       1
# 1648       1
# 1552       1
# 2513       1
# 4466       1
# 2031       1
# 1999       1
# 1967       1
# 1903       1
# 1775       1
# 1711       1
# 1763       1
# 2830       1
# 1955       1
# 2222       1
# 2190       1
# 2117       1
# 1679       1
# Name: description, Length: 2096, dtype: int64

# %%
sns.distplot(train['description'].apply(len),  bins=100)

# %% [markdown]
# ## features

# %%
# features 有较多文本特征, 可以使用wordcloud
from wordcloud import WordCloud
wordcloud = WordCloud(width=900,height=900,background_color='white', max_words=50)
fig = wordcloud.generate(str(train['features']))
plt.figure(figsize=(12,12))
plt.axis('off')
plt.imshow(fig)

# %% [markdown]
# ## building_id、listing_id

# %% [markdown]
# ID型数据,直接舍弃, 保留building_id 作为提交时使用

# %% [markdown]
# ## photos

# %% [markdown]
# 图片处理比较复杂,只进行图片数目的统计

# %%
plt.figure(figsize=(15,6))
sns.countplot(train['photos'].apply(len))
